# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
import tensorflow.keras as keras

# %%
model = keras.applications.resnet50.ResNet50(weights="imagenet")
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 3s 0us/step

# %%
images_resized = tf.image.resize(images,[224,224])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-84884612ead0> in <module>()
# ----> 1 images_resized = tf.image.resize(images,[224,224])
#
# NameError: name 'images' is not defined

# %%
tf.image.crop_and_resize()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3b8841de03c2> in <module>()
# ----> 1 tf.image.crop_and_resize()
#
# TypeError: crop_and_resize_v2() missing 4 required positional arguments: 'image', 'boxes', 'box_indices', and 'crop_size'

# %%
inputs = keras.applications.resnet50.preprocess_input(images_resized*255)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2a2378d04fb5> in <module>()
# ----> 1 inputs = keras.applications.resnet50.preprocess_input(images_resized*255)
#
# NameError: name 'images_resized' is not defined
